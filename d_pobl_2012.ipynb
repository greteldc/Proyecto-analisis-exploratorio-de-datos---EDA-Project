# %% [markdown]
# # I. Preparación del fichero población 2012

# %% [markdown]
# ## I.1. Importamos las librerías necesarias

# %%
from functions import shorten_column_titles
import pandas as pd

# %% [markdown]
# ## I.2. Importamos y exploramos el fichero
# Fuente: https://statbel.fgov.be/nl/open-data/bevolking-naar-woonplaats-nationaliteit-burgerlijke-staat-leeftijd-en-geslacht-12
# El fichero existe en dos formatos: xml (dado el volumen, se nos bloquea la descarga a excel online (máx. 25 MB) por la web => queda solo la opción del formato txt)

# %%
pobl_2012 = pd.read_csv("TF_SOC_POP_STRUCT_2012.txt", sep = "|")
pobl_2012
# Out:
# C:\Users\piovr\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         CD_MUNTY_REFNIS    TX_MUNTY_DESCR_NL    TX_MUNTY_DESCR_FR  \
# 0                 61080                Engis                Engis
# 1                 61068  Villers-Le-Bouillet  Villers-Le-Bouillet
# 2                 61080                Engis                Engis
# 3                 61072                Wanze                Wanze
# 4                 61039              Marchin              Marchin
# ...                 ...                  ...                  ...
# 450537            57064             Péruwelz             Péruwelz
# 450538            57027           Estaimpuis           Estaimpuis
# 450539            93090            Viroinval            Viroinval
# 450540            93090            Viroinval            Viroinval
# 450541            93090            Viroinval            Viroinval
#
#         CD_DSTR_REFNIS          TX_ADM_DSTR_DESCR_NL  \
# 0                61000           Arrondissement Hoei
# 1                61000           Arrondissement Hoei
# 2                61000           Arrondissement Hoei
# 3                61000           Arrondissement Hoei
# 4                61000           Arrondissement Hoei
# ...                ...                           ...
# 450537           57000        Arrondissement Doornik
# 450538           57000        Arrondissement Doornik
# 450539           93000  Arrondissement Philippeville
# 450540           93000  Arrondissement Philippeville
# 450541           93000  Arrondissement Philippeville
#
#                    TX_ADM_DSTR_DESCR_FR CD_PROV_REFNIS      TX_PROV_DESCR_NL  \
# 0                 Arrondissement de Huy          60000        Provincie Luik
# 1                 Arrondissement de Huy          60000        Provincie Luik
# 2                 Arrondissement de Huy          60000        Provincie Luik
# 3                 Arrondissement de Huy          60000        Provincie Luik
# 4                 Arrondissement de Huy          60000        Provincie Luik
# ...                                 ...            ...                   ...
# 450537        Arrondissement de Tournai          50000  Provincie Henegouwen
# 450538        Arrondissement de Tournai          50000  Provincie Henegouwen
# 450539  Arrondissement de Philippeville          90000       Provincie Namen
# 450540  Arrondissement de Philippeville          90000       Provincie Namen
# 450541  Arrondissement de Philippeville          90000       Provincie Namen
#
#            TX_PROV_DESCR_FR  CD_RGN_REFNIS  ... CD_SEX CD_NATLTY TX_NATLTY_FR  \
# 0         Province de Liège           3000  ...      F       BEL       Belges
# 1         Province de Liège           3000  ...      F       BEL       Belges
# 2         Province de Liège           3000  ...      F       BEL       Belges
# 3         Province de Liège           3000  ...      F       BEL       Belges
# 4         Province de Liège           3000  ...      F       BEL       Belges
# ...                     ...            ...  ...    ...       ...          ...
# 450537  Province de Hainaut           3000  ...      F       ETR    Etrangers
# 450538  Province de Hainaut           3000  ...      F       ETR    Etrangers
# 450539    Province de Namur           3000  ...      M       ETR    Etrangers
# 450540    Province de Namur           3000  ...      M       ETR    Etrangers
# 450541    Province de Namur           3000  ...      M       ETR    Etrangers
#
#          TX_NATLTY_NL CD_CIV_STS TX_CIV_STS_FR  TX_CIV_STS_NL CD_AGE  \
# 0              Belgen         20         Marié         Gehuwd     49
# 1              Belgen         20         Marié         Gehuwd     28
# 2              Belgen         20         Marié         Gehuwd     66
# 3              Belgen         20         Marié         Gehuwd     77
# 4              Belgen         20         Marié         Gehuwd     31
# ...               ...        ...           ...            ...    ...
# 450537  Vreemdelingen         40       Divorcé     Gescheiden     48
# 450538  Vreemdelingen         40       Divorcé     Gescheiden     44
# 450539  Vreemdelingen         40       Divorcé     Gescheiden     64
# 450540  Vreemdelingen         40       Divorcé     Gescheiden     62
# 450541  Vreemdelingen         40       Divorcé     Gescheiden     61
#
#        MS_POPULATION  CD_YEAR
# 0                 16     2012
# 1                 16     2012
# 2                 18     2012
# 3                 18     2012
# 4                  8     2012
# ...              ...      ...
# 450537             3     2012
# 450538             3     2012
# 450539             2     2012
# 450540             1     2012
# 450541             3     2012
#
# [450542 rows x 22 columns]

# %%
pobl_2012.shape
# Out:
# (450542, 22)

# %%
pobl_2012.describe(include="all")
# Out:
#         CD_MUNTY_REFNIS TX_MUNTY_DESCR_NL TX_MUNTY_DESCR_FR  CD_DSTR_REFNIS  \
# count     450542.000000            450542            450542   450542.000000
# unique              NaN               589               589             NaN
# top                 NaN         Antwerpen            Anvers             NaN
# freq                NaN              1285              1285             NaN
# mean       45911.830091               NaN               NaN    45871.259505
# std        23966.272274               NaN               NaN    23960.492517
# min        11001.000000               NaN               NaN    11000.000000
# 25%        24038.000000               NaN               NaN    24000.000000
# 50%        44049.000000               NaN               NaN    44000.000000
# 75%        63038.000000               NaN               NaN    63000.000000
# max        93090.000000               NaN               NaN    93000.000000
#
#                   TX_ADM_DSTR_DESCR_NL            TX_ADM_DSTR_DESCR_FR  \
# count                           450542                          450542
# unique                              43                              43
# top     Arrondissement Halle-Vilvoorde  Arrondissement de Hal-Vilvorde
# freq                             27900                           27900
# mean                               NaN                             NaN
# std                                NaN                             NaN
# min                                NaN                             NaN
# 25%                                NaN                             NaN
# 50%                                NaN                             NaN
# 75%                                NaN                             NaN
# max                                NaN                             NaN
#
#        CD_PROV_REFNIS TX_PROV_DESCR_NL   TX_PROV_DESCR_FR  CD_RGN_REFNIS  ...  \
# count          450542           450542             450542  450542.000000  ...
# unique             21               11                 11            NaN  ...
# top             20001   Provincie Luik  Province de Liège            NaN  ...
# freq            47526            60871              60871            NaN  ...
# mean              NaN              NaN                NaN    2524.785703  ...
# std               NaN              NaN                NaN     586.622245  ...
# min               NaN              NaN                NaN    2000.000000  ...
# 25%               NaN              NaN                NaN    2000.000000  ...
# 50%               NaN              NaN                NaN    2000.000000  ...
# 75%               NaN              NaN                NaN    3000.000000  ...
# max               NaN              NaN                NaN    4000.000000  ...
#
#         CD_SEX CD_NATLTY TX_NATLTY_FR TX_NATLTY_NL     CD_CIV_STS  \
# count   450542    450542       450542       450542  450542.000000
# unique       2         2            2            2            NaN
# top          F       BEL       Belges       Belgen            NaN
# freq    232496    307485       307485       307485            NaN
# mean       NaN       NaN          NaN          NaN      22.174825
# std        NaN       NaN          NaN          NaN      11.140173
# min        NaN       NaN          NaN          NaN      10.000000
# 25%        NaN       NaN          NaN          NaN      10.000000
# 50%        NaN       NaN          NaN          NaN      20.000000
# 75%        NaN       NaN          NaN          NaN      30.000000
# max        NaN       NaN          NaN          NaN      40.000000
#
#        TX_CIV_STS_FR  TX_CIV_STS_NL         CD_AGE  MS_POPULATION   CD_YEAR
# count         450542         450542  450542.000000  450542.000000  450542.0
# unique             4              4            NaN            NaN       NaN
# top      Célibataire       Ongehuwd            NaN            NaN       NaN
# freq          153098         153098            NaN            NaN       NaN
# mean             NaN            NaN      51.825907      24.494826    2012.0
# std              NaN            NaN      23.260273      63.363785       0.0
# min              NaN            NaN       0.000000       1.000000    2012.0
# 25%              NaN            NaN      35.000000       2.000000    2012.0
# 50%              NaN            NaN      52.000000       6.000000    2012.0
# 75%              NaN            NaN      70.000000      24.000000    2012.0
# max              NaN            NaN     100.000000    3086.000000    2012.0
#
# [11 rows x 22 columns]

# %%
pobl_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450542 entries, 0 to 450541
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CD_MUNTY_REFNIS       450542 non-null  int64
#  1   TX_MUNTY_DESCR_NL     450542 non-null  object
#  2   TX_MUNTY_DESCR_FR     450542 non-null  object
#  3   CD_DSTR_REFNIS        450542 non-null  int64
#  4   TX_ADM_DSTR_DESCR_NL  450542 non-null  object
#  5   TX_ADM_DSTR_DESCR_FR  450542 non-null  object
#  6   CD_PROV_REFNIS        450542 non-null  object
#  7   TX_PROV_DESCR_NL      450542 non-null  object
#  8   TX_PROV_DESCR_FR      450542 non-null  object
#  9   CD_RGN_REFNIS         450542 non-null  int64
#  10  TX_RGN_DESCR_NL       450542 non-null  object
#  11  TX_RGN_DESCR_FR       450542 non-null  object
#  12  CD_SEX                450542 non-null  object
#  13  CD_NATLTY             450542 non-null  object
#  14  TX_NATLTY_FR          450542 non-null  object
#  15  TX_NATLTY_NL          450542 non-null  object
#  16  CD_CIV_STS            450542 non-null  int64
#  17  TX_CIV_STS_FR         450542 non-null  object
#  18  TX_CIV_STS_NL         450542 non-null  object
#  19  CD_AGE                450542 non-null  int64
#  20  MS_POPULATION         450542 non-null  int64
#  21  CD_YEAR               450542 non-null  int64
# dtypes: int64(7), object(15)
# memory usage: 75.6+ MB

# %% [markdown]
# ## I.3. Limpiamos el dataframe
#
# ### 1.3.1. Quitamos las columnas irrelevantes para nuestro propósito
# Los únicos datos requeridos son: número de habitantes por "arrondissement" => las únicas columnas por guardar son: TX_PROV_DESCR_NL, TX_ADM_DSTR_DESCR_NL + MS_POPULATION

# %%
pobl_2012_col = pobl_2012.loc[:,["TX_PROV_DESCR_NL", "TX_ADM_DSTR_DESCR_NL","MS_POPULATION"]]
pobl_2012_col.head()
# Out:
#   TX_PROV_DESCR_NL TX_ADM_DSTR_DESCR_NL  MS_POPULATION
# 0   Provincie Luik  Arrondissement Hoei             16
# 1   Provincie Luik  Arrondissement Hoei             16
# 2   Provincie Luik  Arrondissement Hoei             18
# 3   Provincie Luik  Arrondissement Hoei             18
# 4   Provincie Luik  Arrondissement Hoei              8

# %%
pobl_2012_col.columns
# Out:
# Index(['TX_PROV_DESCR_NL', 'TX_ADM_DSTR_DESCR_NL', 'MS_POPULATION'], dtype='object')

# %%
#adaptar los nombres de títulos e integrarlos en el dataframe:
pobl_2012_col.columns = shorten_column_titles(pobl_2012_col.columns)
pobl_2012_col.head()
# Out:
#              PROV             ADM_DSTR  MS_POPULATION
# 0  Provincie Luik  Arrondissement Hoei             16
# 1  Provincie Luik  Arrondissement Hoei             16
# 2  Provincie Luik  Arrondissement Hoei             18
# 3  Provincie Luik  Arrondissement Hoei             18
# 4  Provincie Luik  Arrondissement Hoei              8

# %% [markdown]
# ### I.3.2. Tratamos los valores no disponibles (emergidos en el I.2)

# %% [markdown]
# a) Identificamos las columnas concretas dónde se sitúan los valores no disponibles de una manera más visible que por el método .info() en el I.2.

# %%
#guardamos los últimos cambios en la variables pobl_2012
pobl_2012 = pobl_2012_col
pobl_2012_col.isnull().any()
# Out:
# PROV             False
# ADM_DSTR         False
# MS_POPULATION    False
# dtype: bool

# %% [markdown]
# b) Apreciamos la cantidad de valores no disponibles (nº de registros en los cuales se manifiestan)

# %%
pobl_2012.isnull().sum()
# Out:
# PROV             0
# ADM_DSTR         0
# MS_POPULATION    0
# dtype: int64

# %% [markdown]
# c) Con vistas a la sustitución de estos valores: verificamos primero si el número de 21492 corresponde al número de filas que conciernan solo al arrondissement Brussel-Hoofdstad

# %%
#primer sondeo mediante sample:
nan_rows = pobl_2012[pobl_2012.isnull().any(1)]
nan_rows.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18796\4237495627.py in <module>
#       1 #primer sondeo mediante sample:
#       2 nan_rows = pobl_2012[pobl_2012.isnull().any(1)]
# ----> 3 nan_rows.sample(5)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5363             )
#    5364
# -> 5365         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5366         result = self.take(locs, axis=axis)
#    5367         if ignore_index:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
#cuento exacto:
sum(pobl_2012['ADM_DSTR'] == 'Arrondissement Brussel-Hoofdstad')
# Out:
# 21492

# %% [markdown]
# Conclusión: el número de filas sin valor disponible corresponde exactamente al número de filas que contienen "Arrondissement Brussel-Hoofdstad", ni más, ni menos. Por lo tanto, sabemos con certeza que todas las sustituciones se situarán en este "arrondissement". Para no perder datos en posteriores visualizaciones o tratamientos de datos en base a 'provincia', vamos a 'copiar' los valores de arrondissement a la columna de provincia. Así, siempre que llamemos a este dataframe (o de manera más concreta, a sus provincias), estaremos seguros de que no hay ningún valor NaN, y entrarán en consideración siempre los datos de la capital, aunque la 'etiqueta' no pueda considerarse propiamente como una provincia.

# %% [markdown]
# d) Sustituimos todos los valores "NaN" por "Arr. Brussel-Hoofdstad[no Prov]"

# %%
pobl_2012['PROV'] = pobl_2012['PROV'].fillna("Arr. Brussel-Hfdstad[no Prov]")

# %%
#verificamos si ahora nuestro dataframe se ha quedado sin valores NaN
pobl_2012.isnull().sum()
# Out:
# PROV             0
# ADM_DSTR         0
# MS_POPULATION    0
# dtype: int64

# %% [markdown]
# Ya está limpio pobl_2012: no quedan más valores Nan.

# %% [markdown]
# ### I.3.3. Agrupamos las filas por 'provincia' y 'arrondissement' para obtener así el nº total de habitantes por 'arrondissement'. Optamos por mantener las provincias para que todos puedan situar con más facilidad los 'arrondissmenten'.

# %% [markdown]
# ### a) agrupación de número de habitantes a nivel de 'arrondissement'

# %%
pobl_2012_habxarr = pobl_2012.groupby(["PROV","ADM_DSTR"])[["PROV","ADM_DSTR", "MS_POPULATION"]].sum()
pobl_2012_habxarr
# Out:
#                                                             MS_POPULATION
# PROV                      ADM_DSTR
#                           Arrondissement Brussel-Hoofdstad        1138854
# Provincie Antwerpen       Arrondissement Antwerpen                1010001
#                           Arrondissement Mechelen                  329395
#                           Arrondissement Turnhout                  442508
# Provincie Henegouwen      Arrondissement Aat                        84958
#                           Arrondissement Bergen                    254285
#                           Arrondissement Charleroi                 428711
#                           Arrondissement Doornik                   145780
#                           Arrondissement Moeskroen                  73895
#                           Arrondissement Thuin                     150406
#                           Arrondissement Zinnik                    185161
# Provincie Limburg         Arrondissement Hasselt                   414401
#                           Arrondissement Maaseik                   235305
#                           Arrondissement Tongeren                  199698
# Provincie Luik            Arrondissement Borgworm                   77264
#                           Arrondissement Hoei                      109728
#                           Arrondissement Luik                      612740
#                           Arrondissement Verviers                  283668
# Provincie Luxemburg       Arrondissement Aarlen                     59204
#                           Arrondissement Bastenaken                 45705
#                           Arrondissement Marche-en-Famenne          55228
#                           Arrondissement Neufchâteau                60791
#                           Arrondissement Virton                     52710
# Provincie Namen           Arrondissement Dinant                    107593
#                           Arrondissement Namen                     306672
#                           Arrondissement Philippeville              65840
# Provincie Oost-Vlaanderen Arrondissement Aalst                     278667
#                           Arrondissement Dendermonde               195358
#                           Arrondissement Eeklo                      82791
#                           Arrondissement Gent                      535904
#                           Arrondissement Oudenaarde                121199
#                           Arrondissement Sint-Niklaas              240797
# Provincie Vlaams-Brabant  Arrondissement Halle-Vilvoorde           604097
#                           Arrondissement Leuven                    490654
# Provincie Waals-Brabant   Arrondissement Nijvel                    385990
# Provincie West-Vlaanderen Arrondissement Brugge                    278486
#                           Arrondissement Diksmuide                  50262
#                           Arrondissement Ieper                     106415
#                           Arrondissement Kortrijk                  283176
#                           Arrondissement Oostende                  153105
#                           Arrondissement Roeselare                 146706
#                           Arrondissement Tielt                      91065
#                           Arrondissement Veurne                     60775

# %%
#reset index para merge en base a columnas idénticas
pobl_2012_habxarr.reset_index(inplace=True)

# %%
#verificación: nuevo índice? sí
pobl_2012_habxarr
# Out:
#                          PROV                          ADM_DSTR  MS_POPULATION
# 0                              Arrondissement Brussel-Hoofdstad        1138854
# 1         Provincie Antwerpen          Arrondissement Antwerpen        1010001
# 2         Provincie Antwerpen           Arrondissement Mechelen         329395
# 3         Provincie Antwerpen           Arrondissement Turnhout         442508
# 4        Provincie Henegouwen                Arrondissement Aat          84958
# 5        Provincie Henegouwen             Arrondissement Bergen         254285
# 6        Provincie Henegouwen          Arrondissement Charleroi         428711
# 7        Provincie Henegouwen            Arrondissement Doornik         145780
# 8        Provincie Henegouwen          Arrondissement Moeskroen          73895
# 9        Provincie Henegouwen              Arrondissement Thuin         150406
# 10       Provincie Henegouwen             Arrondissement Zinnik         185161
# 11          Provincie Limburg            Arrondissement Hasselt         414401
# 12          Provincie Limburg            Arrondissement Maaseik         235305
# 13          Provincie Limburg           Arrondissement Tongeren         199698
# 14             Provincie Luik           Arrondissement Borgworm          77264
# 15             Provincie Luik               Arrondissement Hoei         109728
# 16             Provincie Luik               Arrondissement Luik         612740
# 17             Provincie Luik           Arrondissement Verviers         283668
# 18        Provincie Luxemburg             Arrondissement Aarlen          59204
# 19        Provincie Luxemburg         Arrondissement Bastenaken          45705
# 20        Provincie Luxemburg  Arrondissement Marche-en-Famenne          55228
# 21        Provincie Luxemburg        Arrondissement Neufchâteau          60791
# 22        Provincie Luxemburg             Arrondissement Virton          52710
# 23            Provincie Namen             Arrondissement Dinant         107593
# 24            Provincie Namen              Arrondissement Namen         306672
# 25            Provincie Namen      Arrondissement Philippeville          65840
# 26  Provincie Oost-Vlaanderen              Arrondissement Aalst         278667
# 27  Provincie Oost-Vlaanderen        Arrondissement Dendermonde         195358
# 28  Provincie Oost-Vlaanderen              Arrondissement Eeklo          82791
# 29  Provincie Oost-Vlaanderen               Arrondissement Gent         535904
# 30  Provincie Oost-Vlaanderen         Arrondissement Oudenaarde         121199
# 31  Provincie Oost-Vlaanderen       Arrondissement Sint-Niklaas         240797
# 32   Provincie Vlaams-Brabant    Arrondissement Halle-Vilvoorde         604097
# 33   Provincie Vlaams-Brabant             Arrondissement Leuven         490654
# 34    Provincie Waals-Brabant             Arrondissement Nijvel         385990
# 35  Provincie West-Vlaanderen             Arrondissement Brugge         278486
# 36  Provincie West-Vlaanderen          Arrondissement Diksmuide          50262
# 37  Provincie West-Vlaanderen              Arrondissement Ieper         106415
# 38  Provincie West-Vlaanderen           Arrondissement Kortrijk         283176
# 39  Provincie West-Vlaanderen           Arrondissement Oostende         153105
# 40  Provincie West-Vlaanderen          Arrondissement Roeselare         146706
# 41  Provincie West-Vlaanderen              Arrondissement Tielt          91065
# 42  Provincie West-Vlaanderen             Arrondissement Veurne          60775

# %% [markdown]
# ### b) agrupación de nº de habitantes por provincia (Bxl: arrondissment)

# %%
pobl_2012_habxprov = pobl_2012_habxarr.groupby("PROV")[["PROV","MS_POPULATION"]].sum()
pobl_2012_habxprov
# Out:
#                            MS_POPULATION
# PROV
#                                  1138854
# Provincie Antwerpen              1781904
# Provincie Henegouwen             1323196
# Provincie Limburg                 849404
# Provincie Luik                   1083400
# Provincie Luxemburg               273638
# Provincie Namen                   480105
# Provincie Oost-Vlaanderen        1454716
# Provincie Vlaams-Brabant         1094751
# Provincie Waals-Brabant           385990
# Provincie West-Vlaanderen        1169990

# %% [markdown]
# ### c) agrupación de nº de habitantes a nivel de país

# %%
hab_2012_BE = pobl_2012["MS_POPULATION"].sum()
hab_2012_BE
# Out:
# 11035948

# %% [markdown]
# ### d) nº de habitantes por "arrondissement": cifras absolutas y proporcionales respecto a la totalidad de la población belga

# %%
pobl_2012_habxarr["PROPORTION_BE"] = pobl_2012_habxarr["MS_POPULATION"]/pobl_2012_habxarr["MS_POPULATION"].sum()
#por haber querido cambiar título nueva columna de PROPORCIÓN a PROPORCIÓN_BE, quitar la penúltima columna PROPORCION
#luego lo mismo con PROPORCIÓN_BE > PROPORTION_BE
#pobl_2012_habxarr.drop("PROPORCIÓN", axis=1, inplace=True)
#pobl_2012_habxarr.drop("PROPORCIÓN_BE", axis = 1, inplace=True)
pobl_2012_habxarr
# Out:
#                          PROV                          ADM_DSTR  \
# 0                              Arrondissement Brussel-Hoofdstad
# 1         Provincie Antwerpen          Arrondissement Antwerpen
# 2         Provincie Antwerpen           Arrondissement Mechelen
# 3         Provincie Antwerpen           Arrondissement Turnhout
# 4        Provincie Henegouwen                Arrondissement Aat
# 5        Provincie Henegouwen             Arrondissement Bergen
# 6        Provincie Henegouwen          Arrondissement Charleroi
# 7        Provincie Henegouwen            Arrondissement Doornik
# 8        Provincie Henegouwen          Arrondissement Moeskroen
# 9        Provincie Henegouwen              Arrondissement Thuin
# 10       Provincie Henegouwen             Arrondissement Zinnik
# 11          Provincie Limburg            Arrondissement Hasselt
# 12          Provincie Limburg            Arrondissement Maaseik
# 13          Provincie Limburg           Arrondissement Tongeren
# 14             Provincie Luik           Arrondissement Borgworm
# 15             Provincie Luik               Arrondissement Hoei
# 16             Provincie Luik               Arrondissement Luik
# 17             Provincie Luik           Arrondissement Verviers
# 18        Provincie Luxemburg             Arrondissement Aarlen
# 19        Provincie Luxemburg         Arrondissement Bastenaken
# 20        Provincie Luxemburg  Arrondissement Marche-en-Famenne
# 21        Provincie Luxemburg        Arrondissement Neufchâteau
# 22        Provincie Luxemburg             Arrondissement Virton
# 23            Provincie Namen             Arrondissement Dinant
# 24            Provincie Namen              Arrondissement Namen
# 25            Provincie Namen      Arrondissement Philippeville
# 26  Provincie Oost-Vlaanderen              Arrondissement Aalst
# 27  Provincie Oost-Vlaanderen        Arrondissement Dendermonde
# 28  Provincie Oost-Vlaanderen              Arrondissement Eeklo
# 29  Provincie Oost-Vlaanderen               Arrondissement Gent
# 30  Provincie Oost-Vlaanderen         Arrondissement Oudenaarde
# 31  Provincie Oost-Vlaanderen       Arrondissement Sint-Niklaas
# 32   Provincie Vlaams-Brabant    Arrondissement Halle-Vilvoorde
# 33   Provincie Vlaams-Brabant             Arrondissement Leuven
# 34    Provincie Waals-Brabant             Arrondissement Nijvel
# 35  Provincie West-Vlaanderen             Arrondissement Brugge
# 36  Provincie West-Vlaanderen          Arrondissement Diksmuide
# 37  Provincie West-Vlaanderen              Arrondissement Ieper
# 38  Provincie West-Vlaanderen           Arrondissement Kortrijk
# 39  Provincie West-Vlaanderen           Arrondissement Oostende
# 40  Provincie West-Vlaanderen          Arrondissement Roeselare
# 41  Provincie West-Vlaanderen              Arrondissement Tielt
# 42  Provincie West-Vlaanderen             Arrondissement Veurne
#
#     MS_POPULATION  PROPORTION_BE
# 0         1138854       0.103195
# 1         1010001       0.091519
# 2          329395       0.029847
# 3          442508       0.040097
# 4           84958       0.007698
# 5          254285       0.023042
# 6          428711       0.038847
# 7          145780       0.013210
# 8           73895       0.006696
# 9          150406       0.013629
# 10         185161       0.016778
# 11         414401       0.037550
# 12         235305       0.021322
# 13         199698       0.018095
# 14          77264       0.007001
# 15         109728       0.009943
# 16         612740       0.055522
# 17         283668       0.025704
# 18          59204       0.005365
# 19          45705       0.004141
# 20          55228       0.005004
# 21          60791       0.005508
# 22          52710       0.004776
# 23         107593       0.009749
# 24         306672       0.027788
# 25          65840       0.005966
# 26         278667       0.025251
# 27         195358       0.017702
# 28          82791       0.007502
# 29         535904       0.048560
# 30         121199       0.010982
# 31         240797       0.021819
# 32         604097       0.054739
# 33         490654       0.044460
# 34         385990       0.034976
# 35         278486       0.025234
# 36          50262       0.004554
# 37         106415       0.009643
# 38         283176       0.025659
# 39         153105       0.013873
# 40         146706       0.013293
# 41          91065       0.008252
# 42          60775       0.005507

# %% [markdown]
# ### e) nº de habitantes por "provincia": cifras absolutas y proporcionales respecto a la totalidad de la población belga

# %%
pobl_2012_habxprov["PROPORCIÓN_BE"] = pobl_2012_habxprov["MS_POPULATION"]/pobl_2012_habxprov["MS_POPULATION"].sum()
pobl_2012_habxprov
# Out:
#                            MS_POPULATION  PROPORCIÓN_BE
# PROV
#                                  1138854       0.103195
# Provincie Antwerpen              1781904       0.161464
# Provincie Henegouwen             1323196       0.119899
# Provincie Limburg                 849404       0.076967
# Provincie Luik                   1083400       0.098170
# Provincie Luxemburg               273638       0.024795
# Provincie Namen                   480105       0.043504
# Provincie Oost-Vlaanderen        1454716       0.131816
# Provincie Vlaams-Brabant         1094751       0.099199
# Provincie Waals-Brabant           385990       0.034976
# Provincie West-Vlaanderen        1169990       0.106016

# %% [markdown]
# ## I.4 Preparación de ficheros para exportar

# %%
pobl_2012_habxarr.to_csv("Data_ACC/pobl_2012_habxarr.csv", index = False)
pobl_2012_habxprov.to_csv("Data_ACC/pobl_2012_habxprov.csv", index = False)
#cambios para hab_2012_BE porque como numpy.array no admite escritura a csv
hab_2012_BE.tofile('Data_acc/hab_2012_BE.csv', sep = ',')
