# %% [markdown]
# # I. Preparación del fichero población 2018

# %% [markdown]
# ## I.1. Importamos las librerías necesarias

# %%
from functions import shorten_column_titles
import pandas as pd
import numpy as np

# %% [markdown]
# ## I.2. Importamos y exploramos el fichero
# Fuente: https://statbel.fgov.be/nl/open-data/bevolking-naar-woonplaats-nationaliteit-burgerlijke-staat-leeftijd-en-geslacht-12
# El fichero existe en dos formatos: xml (dado el volumen, se nos bloquea la descarga a excel online (máx. 25 MB) por la web => queda solo la opción del formato txt)

# %%
pobl_2018 = pd.read_csv("TF_SOC_POP_STRUCT_2018.txt", sep = "|")
pobl_2018
# Out:
# C:\Users\piovr\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         CD_MUNTY_REFNIS TX_MUNTY_DESCR_NL TX_MUNTY_DESCR_FR  CD_DSTR_REFNIS  \
# 0                 71024      Herk-de-Stad    Herck-la-Ville           71000
# 1                 71037            Lummen            Lummen           71000
# 2                 71011        Diepenbeek        Diepenbeek           71000
# 3                 71016              Genk              Genk           71000
# 4                 71017          Gingelom          Gingelom           71000
# ...                 ...               ...               ...             ...
# 465413            92141        La Bruyère        La Bruyère           92000
# 465414            46024           Stekene           Stekene           46000
# 465415            46024           Stekene           Stekene           46000
# 465416            46024           Stekene           Stekene           46000
# 465417            92141        La Bruyère        La Bruyère           92000
#
#                TX_ADM_DSTR_DESCR_NL             TX_ADM_DSTR_DESCR_FR  \
# 0            Arrondissement Hasselt        Arrondissement de Hasselt
# 1            Arrondissement Hasselt        Arrondissement de Hasselt
# 2            Arrondissement Hasselt        Arrondissement de Hasselt
# 3            Arrondissement Hasselt        Arrondissement de Hasselt
# 4            Arrondissement Hasselt        Arrondissement de Hasselt
# ...                             ...                              ...
# 465413         Arrondissement Namen          Arrondissement de Namur
# 465414  Arrondissement Sint-Niklaas  Arrondissement de Saint-Nicolas
# 465415  Arrondissement Sint-Niklaas  Arrondissement de Saint-Nicolas
# 465416  Arrondissement Sint-Niklaas  Arrondissement de Saint-Nicolas
# 465417         Arrondissement Namen          Arrondissement de Namur
#
#        CD_PROV_REFNIS           TX_PROV_DESCR_NL  \
# 0               70000          Provincie Limburg
# 1               70000          Provincie Limburg
# 2               70000          Provincie Limburg
# 3               70000          Provincie Limburg
# 4               70000          Provincie Limburg
# ...               ...                        ...
# 465413          90000            Provincie Namen
# 465414          40000  Provincie Oost-Vlaanderen
# 465415          40000  Provincie Oost-Vlaanderen
# 465416          40000  Provincie Oost-Vlaanderen
# 465417          90000            Provincie Namen
#
#                      TX_PROV_DESCR_FR  CD_RGN_REFNIS  ... CD_SEX CD_NATLTY  \
# 0                Province de Limbourg           2000  ...      F       BEL
# 1                Province de Limbourg           2000  ...      M       BEL
# 2                Province de Limbourg           2000  ...      F       BEL
# 3                Province de Limbourg           2000  ...      M       BEL
# 4                Province de Limbourg           2000  ...      F       BEL
# ...                               ...            ...  ...    ...       ...
# 465413              Province de Namur           3000  ...      F       ETR
# 465414  Province de Flandre orientale           2000  ...      M       ETR
# 465415  Province de Flandre orientale           2000  ...      M       ETR
# 465416  Province de Flandre orientale           2000  ...      M       ETR
# 465417              Province de Namur           3000  ...      F       ETR
#
#        TX_NATLTY_FR   TX_NATLTY_NL CD_CIV_STS TX_CIV_STS_FR  TX_CIV_STS_NL  \
# 0            Belges         Belgen         20         Marié         Gehuwd
# 1            Belges         Belgen         20         Marié         Gehuwd
# 2            Belges         Belgen         20         Marié         Gehuwd
# 3            Belges         Belgen         20         Marié         Gehuwd
# 4            Belges         Belgen         20         Marié         Gehuwd
# ...             ...            ...        ...           ...            ...
# 465413    Etrangers  Vreemdelingen         40       Divorcé     Gescheiden
# 465414    Etrangers  Vreemdelingen         40       Divorcé     Gescheiden
# 465415    Etrangers  Vreemdelingen         40       Divorcé     Gescheiden
# 465416    Etrangers  Vreemdelingen         40       Divorcé     Gescheiden
# 465417    Etrangers  Vreemdelingen         40       Divorcé     Gescheiden
#
#        CD_AGE MS_POPULATION  CD_YEAR
# 0          39            42     2018
# 1          82            24     2018
# 2          42            51     2018
# 3          63           277     2018
# 4          30            14     2018
# ...       ...           ...      ...
# 465413     64             1     2018
# 465414     67             2     2018
# 465415     74             1     2018
# 465416     81             1     2018
# 465417     63             1     2018
#
# [465418 rows x 22 columns]

# %%
pobl_2018.shape
# Out:
# (465418, 22)

# %%
pobl_2018.describe(include="all")
# Out:
#         CD_MUNTY_REFNIS TX_MUNTY_DESCR_NL TX_MUNTY_DESCR_FR  CD_DSTR_REFNIS  \
# count     465418.000000            465418            465418   465418.000000
# unique              NaN               589               589             NaN
# top                 NaN         Antwerpen            Anvers             NaN
# freq                NaN              1293              1293             NaN
# mean       45795.085029               NaN               NaN    45754.592646
# std        23956.614057               NaN               NaN    23950.946921
# min        11001.000000               NaN               NaN    11000.000000
# 25%        24033.000000               NaN               NaN    24000.000000
# 50%        44043.000000               NaN               NaN    44000.000000
# 75%        63035.000000               NaN               NaN    63000.000000
# max        93090.000000               NaN               NaN    93000.000000
#
#                   TX_ADM_DSTR_DESCR_NL            TX_ADM_DSTR_DESCR_FR  \
# count                           465418                          465418
# unique                              43                              43
# top     Arrondissement Halle-Vilvoorde  Arrondissement de Hal-Vilvorde
# freq                             29061                           29061
# mean                               NaN                             NaN
# std                                NaN                             NaN
# min                                NaN                             NaN
# 25%                                NaN                             NaN
# 50%                                NaN                             NaN
# 75%                                NaN                             NaN
# max                                NaN                             NaN
#
#        CD_PROV_REFNIS TX_PROV_DESCR_NL   TX_PROV_DESCR_FR  CD_RGN_REFNIS  ...  \
# count          465418           465418             465418  465418.000000  ...
# unique             21               11                 11            NaN  ...
# top             20001   Provincie Luik  Province de Liège            NaN  ...
# freq            48299            62163              62163            NaN  ...
# mean              NaN              NaN                NaN    2517.923673  ...
# std               NaN              NaN                NaN     584.591526  ...
# min               NaN              NaN                NaN    2000.000000  ...
# 25%               NaN              NaN                NaN    2000.000000  ...
# 50%               NaN              NaN                NaN    2000.000000  ...
# 75%               NaN              NaN                NaN    3000.000000  ...
# max               NaN              NaN                NaN    4000.000000  ...
#
#         CD_SEX CD_NATLTY TX_NATLTY_FR TX_NATLTY_NL     CD_CIV_STS  \
# count   465418    465418       465418       465418  465418.000000
# unique       2         2            2            2            NaN
# top          F       BEL       Belges       Belgen            NaN
# freq    239526    309736       309736       309736            NaN
# mean       NaN       NaN          NaN          NaN      22.086554
# std        NaN       NaN          NaN          NaN      11.218918
# min        NaN       NaN          NaN          NaN      10.000000
# 25%        NaN       NaN          NaN          NaN      10.000000
# 50%        NaN       NaN          NaN          NaN      20.000000
# 75%        NaN       NaN          NaN          NaN      30.000000
# max        NaN       NaN          NaN          NaN      40.000000
#
#        TX_CIV_STS_FR  TX_CIV_STS_NL         CD_AGE  MS_POPULATION   CD_YEAR
# count         465418         465418  465418.000000  465418.000000  465418.0
# unique             4              4            NaN            NaN       NaN
# top      Célibataire       Ongehuwd            NaN            NaN       NaN
# freq          161782         161782            NaN            NaN       NaN
# mean             NaN            NaN      52.607527      24.442695    2018.0
# std              NaN            NaN      23.467469      63.746827       0.0
# min              NaN            NaN       0.000000       1.000000    2018.0
# 25%              NaN            NaN      35.000000       2.000000    2018.0
# 50%              NaN            NaN      53.000000       7.000000    2018.0
# 75%              NaN            NaN      71.000000      25.000000    2018.0
# max              NaN            NaN     100.000000    2936.000000    2018.0
#
# [11 rows x 22 columns]

# %%
pobl_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465418 entries, 0 to 465417
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CD_MUNTY_REFNIS       465418 non-null  int64
#  1   TX_MUNTY_DESCR_NL     465418 non-null  object
#  2   TX_MUNTY_DESCR_FR     465418 non-null  object
#  3   CD_DSTR_REFNIS        465418 non-null  int64
#  4   TX_ADM_DSTR_DESCR_NL  465418 non-null  object
#  5   TX_ADM_DSTR_DESCR_FR  465418 non-null  object
#  6   CD_PROV_REFNIS        465418 non-null  object
#  7   TX_PROV_DESCR_NL      465418 non-null  object
#  8   TX_PROV_DESCR_FR      465418 non-null  object
#  9   CD_RGN_REFNIS         465418 non-null  int64
#  10  TX_RGN_DESCR_NL       465418 non-null  object
#  11  TX_RGN_DESCR_FR       465418 non-null  object
#  12  CD_SEX                465418 non-null  object
#  13  CD_NATLTY             465418 non-null  object
#  14  TX_NATLTY_FR          465418 non-null  object
#  15  TX_NATLTY_NL          465418 non-null  object
#  16  CD_CIV_STS            465418 non-null  int64
#  17  TX_CIV_STS_FR         465418 non-null  object
#  18  TX_CIV_STS_NL         465418 non-null  object
#  19  CD_AGE                465418 non-null  int64
#  20  MS_POPULATION         465418 non-null  int64
#  21  CD_YEAR               465418 non-null  int64
# dtypes: int64(7), object(15)
# memory usage: 78.1+ MB

# %% [markdown]
# ## I.3. Limpiamos el dataframe
#
# ### 1.3.1. Quitamos las columnas irrelevantes para nuestro propósito
# Los únicos datos requeridos son: número de habitantes por "arrondissement" => las únicas columnas por guardar son: TX_PROV_DESCR_NL, TX_ADM_DSTR_DESCR_NL + MS_POPULATION

# %%
pobl_2018_col = pobl_2018.loc[:,["TX_PROV_DESCR_NL", "TX_ADM_DSTR_DESCR_NL","MS_POPULATION"]]
pobl_2018_col.head()
# Out:
#     TX_PROV_DESCR_NL    TX_ADM_DSTR_DESCR_NL  MS_POPULATION
# 0  Provincie Limburg  Arrondissement Hasselt             42
# 1  Provincie Limburg  Arrondissement Hasselt             24
# 2  Provincie Limburg  Arrondissement Hasselt             51
# 3  Provincie Limburg  Arrondissement Hasselt            277
# 4  Provincie Limburg  Arrondissement Hasselt             14

# %%
pobl_2018_col.columns
# Out:
# Index(['TX_PROV_DESCR_NL', 'TX_ADM_DSTR_DESCR_NL', 'MS_POPULATION'], dtype='object')

# %%
#adaptar los nombres de títulos e integrarlos en el dataframe:
pobl_2018_col.columns = shorten_column_titles(pobl_2018_col.columns)
pobl_2018_col.head()
# Out:
#                 PROV                ADM_DSTR  MS_POPULATION
# 0  Provincie Limburg  Arrondissement Hasselt             42
# 1  Provincie Limburg  Arrondissement Hasselt             24
# 2  Provincie Limburg  Arrondissement Hasselt             51
# 3  Provincie Limburg  Arrondissement Hasselt            277
# 4  Provincie Limburg  Arrondissement Hasselt             14

# %% [markdown]
# ### I.3.2. Tratamos los valores no disponibles (emergidos en el I.2)

# %% [markdown]
# a) Identificamos las columnas concretas dónde se sitúan los valores no disponibles de una manera más visible que por el método .info() en el I.2.

# %%
#guardamos los últimos cambios en la variables pobl_2018
pobl_2018 = pobl_2018_col
pobl_2018_col.isnull().any()
# Out:
# PROV             False
# ADM_DSTR         False
# MS_POPULATION    False
# dtype: bool

# %% [markdown]
# b) Apreciamos la cantidad de valores no disponibles (nº de registros en los cuales se manifiestan)

# %%
pobl_2018.isnull().sum()
# Out:
# PROV             0
# ADM_DSTR         0
# MS_POPULATION    0
# dtype: int64

# %% [markdown]
# c) Con vistas a la sustitución de estos valores: verificamos primero si el número de 21492 corresponde al número de filas que conciernan solo al arrondissement Brussel-Hoofdstad

# %%
#primer sondeo mediante sample:
nan_rows = pobl_2018[pobl_2018.isnull().any(1)]
nan_rows.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28644\1206387118.py in <module>
#       1 #primer sondeo mediante sample:
#       2 nan_rows = pobl_2018[pobl_2018.isnull().any(1)]
# ----> 3 nan_rows.sample(5)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5363             )
#    5364
# -> 5365         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5366         result = self.take(locs, axis=axis)
#    5367         if ignore_index:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
#cuento exacto:
sum(pobl_2018['ADM_DSTR'] == 'Arrondissement Brussel-Hoofdstad')
# Out:
# 21425

# %% [markdown]
# Conclusión: el número de filas sin valor disponible corresponde exactamente al número de filas que contienen "Arrondissement Brussel-Hoofdstad", ni más, ni menos. Por lo tanto, sabemos con certeza que todas las sustituciones se situarán en este "arrondissement". Para no perder datos en posteriores visualizaciones o tratamientos de datos en base a 'provincia', vamos a 'copiar' los valores de arrondissement a la columna de provincia. Así, siempre que llamemos a este dataframe (o de manera más concreta, a sus provincias), estaremos seguros de que no hay ningún valor NaN, y entrarán en consideración siempre los datos de la capital, aunque la 'etiqueta' no pueda considerarse propiamente como una provincia.

# %% [markdown]
# d) Sustituimos todos los valores "NaN" por "Arr. Brussel-Hoofdstad[no Prov]"

# %%
pobl_2018['PROV'] = pobl_2018['PROV'].fillna("Arr. Brussel-Hfdstad[no Prov]")

# %%
pobl_2018["PROV"].unique()
# Out:
# array(['Provincie Limburg', 'Provincie Luik', 'Provincie Antwerpen',
#        'Provincie Oost-Vlaanderen', 'Provincie West-Vlaanderen',
#        'Provincie Waals-Brabant', 'Provincie Vlaams-Brabant', ' ',
#        'Provincie Luxemburg', 'Provincie Namen', 'Provincie Henegouwen'],
#       dtype=object)

# %%
#verificamos si ahora nuestro dataframe se ha quedado sin valores NaN
pobl_2018.isnull().sum()
# Out:
# PROV             0
# ADM_DSTR         0
# MS_POPULATION    0
# dtype: int64

# %% [markdown]
# Ya está limpio pobl_2018: no quedan más valores Nan.

# %% [markdown]
# ### I.3.3. Agrupamos las filas por 'provincia' y 'arrondissement' para obtener así el nº total de habitantes por 'arrondissement'. Optamos por mantener las provincias para que todos puedan situar con más facilidad los 'arrondissmenten'.

# %% [markdown]
# ### a) agrupación de número de habitantes a nivel de 'arrondissement'

# %%
pobl_2018_habxarr = pobl_2018.groupby(["PROV","ADM_DSTR"])[["PROV","ADM_DSTR", "MS_POPULATION"]].sum()
pobl_2018_habxarr
# Out:
#                                                             MS_POPULATION
# PROV                      ADM_DSTR
#                           Arrondissement Brussel-Hoofdstad        1198726
# Provincie Antwerpen       Arrondissement Antwerpen                1045593
#                           Arrondissement Mechelen                  342945
#                           Arrondissement Turnhout                  458948
# Provincie Henegouwen      Arrondissement Aat                        86782
#                           Arrondissement Bergen                    258608
#                           Arrondissement Charleroi                 430701
#                           Arrondissement Doornik                   147011
#                           Arrondissement Moeskroen                  76297
#                           Arrondissement Thuin                     151912
#                           Arrondissement Zinnik                    190334
# Provincie Limburg         Arrondissement Hasselt                   427010
#                           Arrondissement Maaseik                   240511
#                           Arrondissement Tongeren                  203359
# Provincie Luik            Arrondissement Borgworm                   80902
#                           Arrondissement Hoei                      113097
#                           Arrondissement Luik                      623953
#                           Arrondissement Verviers                  287374
# Provincie Luxemburg       Arrondissement Aarlen                     62202
#                           Arrondissement Bastenaken                 48183
#                           Arrondissement Marche-en-Famenne          56143
#                           Arrondissement Neufchâteau                63041
#                           Arrondissement Virton                     53658
# Provincie Namen           Arrondissement Dinant                    110610
#                           Arrondissement Namen                     316058
#                           Arrondissement Philippeville              66405
# Provincie Oost-Vlaanderen Arrondissement Aalst                     289175
#                           Arrondissement Dendermonde               200307
#                           Arrondissement Eeklo                      84591
#                           Arrondissement Gent                      556916
#                           Arrondissement Oudenaarde                123868
#                           Arrondissement Sint-Niklaas              250196
# Provincie Vlaams-Brabant  Arrondissement Halle-Vilvoorde           632134
#                           Arrondissement Leuven                    506355
# Provincie Waals-Brabant   Arrondissement Nijvel                    401106
# Provincie West-Vlaanderen Arrondissement Brugge                    281780
#                           Arrondissement Diksmuide                  51428
#                           Arrondissement Ieper                     106251
#                           Arrondissement Kortrijk                  289114
#                           Arrondissement Oostende                  156468
#                           Arrondissement Roeselare                 151873
#                           Arrondissement Tielt                      92615
#                           Arrondissement Veurne                     61530

# %%
#reset index para merge en base a columnas idénticas
pobl_2018_habxarr.reset_index(inplace=True)

# %%
#verificación: nuevo índice? sí
pobl_2018_habxarr
# Out:
#                          PROV                          ADM_DSTR  MS_POPULATION
# 0                              Arrondissement Brussel-Hoofdstad        1198726
# 1         Provincie Antwerpen          Arrondissement Antwerpen        1045593
# 2         Provincie Antwerpen           Arrondissement Mechelen         342945
# 3         Provincie Antwerpen           Arrondissement Turnhout         458948
# 4        Provincie Henegouwen                Arrondissement Aat          86782
# 5        Provincie Henegouwen             Arrondissement Bergen         258608
# 6        Provincie Henegouwen          Arrondissement Charleroi         430701
# 7        Provincie Henegouwen            Arrondissement Doornik         147011
# 8        Provincie Henegouwen          Arrondissement Moeskroen          76297
# 9        Provincie Henegouwen              Arrondissement Thuin         151912
# 10       Provincie Henegouwen             Arrondissement Zinnik         190334
# 11          Provincie Limburg            Arrondissement Hasselt         427010
# 12          Provincie Limburg            Arrondissement Maaseik         240511
# 13          Provincie Limburg           Arrondissement Tongeren         203359
# 14             Provincie Luik           Arrondissement Borgworm          80902
# 15             Provincie Luik               Arrondissement Hoei         113097
# 16             Provincie Luik               Arrondissement Luik         623953
# 17             Provincie Luik           Arrondissement Verviers         287374
# 18        Provincie Luxemburg             Arrondissement Aarlen          62202
# 19        Provincie Luxemburg         Arrondissement Bastenaken          48183
# 20        Provincie Luxemburg  Arrondissement Marche-en-Famenne          56143
# 21        Provincie Luxemburg        Arrondissement Neufchâteau          63041
# 22        Provincie Luxemburg             Arrondissement Virton          53658
# 23            Provincie Namen             Arrondissement Dinant         110610
# 24            Provincie Namen              Arrondissement Namen         316058
# 25            Provincie Namen      Arrondissement Philippeville          66405
# 26  Provincie Oost-Vlaanderen              Arrondissement Aalst         289175
# 27  Provincie Oost-Vlaanderen        Arrondissement Dendermonde         200307
# 28  Provincie Oost-Vlaanderen              Arrondissement Eeklo          84591
# 29  Provincie Oost-Vlaanderen               Arrondissement Gent         556916
# 30  Provincie Oost-Vlaanderen         Arrondissement Oudenaarde         123868
# 31  Provincie Oost-Vlaanderen       Arrondissement Sint-Niklaas         250196
# 32   Provincie Vlaams-Brabant    Arrondissement Halle-Vilvoorde         632134
# 33   Provincie Vlaams-Brabant             Arrondissement Leuven         506355
# 34    Provincie Waals-Brabant             Arrondissement Nijvel         401106
# 35  Provincie West-Vlaanderen             Arrondissement Brugge         281780
# 36  Provincie West-Vlaanderen          Arrondissement Diksmuide          51428
# 37  Provincie West-Vlaanderen              Arrondissement Ieper         106251
# 38  Provincie West-Vlaanderen           Arrondissement Kortrijk         289114
# 39  Provincie West-Vlaanderen           Arrondissement Oostende         156468
# 40  Provincie West-Vlaanderen          Arrondissement Roeselare         151873
# 41  Provincie West-Vlaanderen              Arrondissement Tielt          92615
# 42  Provincie West-Vlaanderen             Arrondissement Veurne          61530

# %% [markdown]
# ### b) agrupación de nº de habitantes por provincia (Bxl: arrondissment)

# %%
pobl_2018_habxprov = pobl_2018_habxarr.groupby("PROV")[["PROV","MS_POPULATION"]].sum()
pobl_2018_habxprov
# Out:
#                            MS_POPULATION
# PROV
#                                  1198726
# Provincie Antwerpen              1847486
# Provincie Henegouwen             1341645
# Provincie Limburg                 870880
# Provincie Luik                   1105326
# Provincie Luxemburg               283227
# Provincie Namen                   493073
# Provincie Oost-Vlaanderen        1505053
# Provincie Vlaams-Brabant         1138489
# Provincie Waals-Brabant           401106
# Provincie West-Vlaanderen        1191059

# %% [markdown]
# ### c) agrupación de nº de habitantes a nivel de país

# %%
hab_2018_BE = pobl_2018["MS_POPULATION"].sum()
hab_2018_BE
# Out:
# 11376070

# %% [markdown]
# ### d) nº de habitantes por "arrondissement": cifras absolutas y proporcionales respecto a la totalidad de la población belga

# %%
pobl_2018_habxarr["PROPORTION_BE"] = pobl_2018_habxarr["MS_POPULATION"]/pobl_2018_habxarr["MS_POPULATION"].sum()
#por haber querido cambiar título nueva columna de PROPORCIÓN a PROPORCIÓN_BE, quitar la penúltima columna PROPORCION
#luego lo mismo con PROPORCIÓN_BE > PROPORTION_BE
#pobl_2018_habxarr.drop("PROPORCIÓN", axis=1, inplace=True)
#pobl_2018_habxarr.drop("PROPORCIÓN_BE", axis = 1, inplace=True)
pobl_2018_habxarr
# Out:
#                          PROV                          ADM_DSTR  \
# 0                              Arrondissement Brussel-Hoofdstad
# 1         Provincie Antwerpen          Arrondissement Antwerpen
# 2         Provincie Antwerpen           Arrondissement Mechelen
# 3         Provincie Antwerpen           Arrondissement Turnhout
# 4        Provincie Henegouwen                Arrondissement Aat
# 5        Provincie Henegouwen             Arrondissement Bergen
# 6        Provincie Henegouwen          Arrondissement Charleroi
# 7        Provincie Henegouwen            Arrondissement Doornik
# 8        Provincie Henegouwen          Arrondissement Moeskroen
# 9        Provincie Henegouwen              Arrondissement Thuin
# 10       Provincie Henegouwen             Arrondissement Zinnik
# 11          Provincie Limburg            Arrondissement Hasselt
# 12          Provincie Limburg            Arrondissement Maaseik
# 13          Provincie Limburg           Arrondissement Tongeren
# 14             Provincie Luik           Arrondissement Borgworm
# 15             Provincie Luik               Arrondissement Hoei
# 16             Provincie Luik               Arrondissement Luik
# 17             Provincie Luik           Arrondissement Verviers
# 18        Provincie Luxemburg             Arrondissement Aarlen
# 19        Provincie Luxemburg         Arrondissement Bastenaken
# 20        Provincie Luxemburg  Arrondissement Marche-en-Famenne
# 21        Provincie Luxemburg        Arrondissement Neufchâteau
# 22        Provincie Luxemburg             Arrondissement Virton
# 23            Provincie Namen             Arrondissement Dinant
# 24            Provincie Namen              Arrondissement Namen
# 25            Provincie Namen      Arrondissement Philippeville
# 26  Provincie Oost-Vlaanderen              Arrondissement Aalst
# 27  Provincie Oost-Vlaanderen        Arrondissement Dendermonde
# 28  Provincie Oost-Vlaanderen              Arrondissement Eeklo
# 29  Provincie Oost-Vlaanderen               Arrondissement Gent
# 30  Provincie Oost-Vlaanderen         Arrondissement Oudenaarde
# 31  Provincie Oost-Vlaanderen       Arrondissement Sint-Niklaas
# 32   Provincie Vlaams-Brabant    Arrondissement Halle-Vilvoorde
# 33   Provincie Vlaams-Brabant             Arrondissement Leuven
# 34    Provincie Waals-Brabant             Arrondissement Nijvel
# 35  Provincie West-Vlaanderen             Arrondissement Brugge
# 36  Provincie West-Vlaanderen          Arrondissement Diksmuide
# 37  Provincie West-Vlaanderen              Arrondissement Ieper
# 38  Provincie West-Vlaanderen           Arrondissement Kortrijk
# 39  Provincie West-Vlaanderen           Arrondissement Oostende
# 40  Provincie West-Vlaanderen          Arrondissement Roeselare
# 41  Provincie West-Vlaanderen              Arrondissement Tielt
# 42  Provincie West-Vlaanderen             Arrondissement Veurne
#
#     MS_POPULATION  PROPORTION_BE
# 0         1198726       0.105373
# 1         1045593       0.091912
# 2          342945       0.030146
# 3          458948       0.040343
# 4           86782       0.007628
# 5          258608       0.022733
# 6          430701       0.037860
# 7          147011       0.012923
# 8           76297       0.006707
# 9          151912       0.013354
# 10         190334       0.016731
# 11         427010       0.037536
# 12         240511       0.021142
# 13         203359       0.017876
# 14          80902       0.007112
# 15         113097       0.009942
# 16         623953       0.054848
# 17         287374       0.025261
# 18          62202       0.005468
# 19          48183       0.004235
# 20          56143       0.004935
# 21          63041       0.005542
# 22          53658       0.004717
# 23         110610       0.009723
# 24         316058       0.027783
# 25          66405       0.005837
# 26         289175       0.025420
# 27         200307       0.017608
# 28          84591       0.007436
# 29         556916       0.048955
# 30         123868       0.010888
# 31         250196       0.021993
# 32         632134       0.055567
# 33         506355       0.044511
# 34         401106       0.035259
# 35         281780       0.024770
# 36          51428       0.004521
# 37         106251       0.009340
# 38         289114       0.025414
# 39         156468       0.013754
# 40         151873       0.013350
# 41          92615       0.008141
# 42          61530       0.005409

# %% [markdown]
# ### e) nº de habitantes por "provincia": cifras absolutas y proporcionales respecto a la totalidad de la población belga

# %%
pobl_2018_habxprov["PROPORCIÓN_BE"] = pobl_2018_habxprov["MS_POPULATION"]/pobl_2018_habxprov["MS_POPULATION"].sum()
pobl_2018_habxprov
# Out:
#                            MS_POPULATION  PROPORCIÓN_BE
# PROV
#                                  1198726       0.105373
# Provincie Antwerpen              1847486       0.162401
# Provincie Henegouwen             1341645       0.117936
# Provincie Limburg                 870880       0.076554
# Provincie Luik                   1105326       0.097162
# Provincie Luxemburg               283227       0.024897
# Provincie Namen                   493073       0.043343
# Provincie Oost-Vlaanderen        1505053       0.132300
# Provincie Vlaams-Brabant         1138489       0.100078
# Provincie Waals-Brabant           401106       0.035259
# Provincie West-Vlaanderen        1191059       0.104699

# %% [markdown]
# ## I.4. Preparación de ficheros para exportar

# %%
pobl_2018_habxarr.to_csv("Data_ACC/pobl_2018_habxarr.csv", index = False)
pobl_2018_habxprov.to_csv("Data_ACC/pobl_2018_habxprov.csv", index = False)
#cambios para hab_2018_BE porque como numpy.array no admite escritura a csv
hab_2018_BE.tofile('Data_ACC/hab_2018_BE.csv', sep = ',')
