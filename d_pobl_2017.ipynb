# %% [markdown]
# # I. Preparación del fichero población 2017

# %% [markdown]
# ## I.1. Importamos las librerías necesarias

# %%
from functions import shorten_column_titles
import pandas as pd

# %% [markdown]
# ## I.2. Importamos y exploramos el fichero
# Fuente: https://statbel.fgov.be/nl/open-data/bevolking-naar-woonplaats-nationaliteit-burgerlijke-staat-leeftijd-en-geslacht-12
# El fichero existe en dos formatos: xml (dado el volumen, se nos bloquea la descarga a excel online (máx. 25 MB) por la web => queda solo la opción del formato txt)

# %%
pobl_2017 = pd.read_csv("TF_SOC_POP_STRUCT_2017.txt", sep = "|")
pobl_2017
# Out:
# C:\Users\piovr\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         CD_MUNTY_REFNIS TX_MUNTY_DESCR_NL TX_MUNTY_DESCR_FR  CD_DSTR_REFNIS  \
# 0                 64076            Faimes            Faimes           64000
# 1                 64075         Wasseiges         Wasseiges           64000
# 2                 71016              Genk              Genk           71000
# 3                 71002                As                As           71000
# 4                 71016              Genk              Genk           71000
# ...                 ...               ...               ...             ...
# 462775            93022         Florennes         Florennes           93000
# 462776            52043            Manage            Manage           52000
# 462777            52043            Manage            Manage           52000
# 462778            52043            Manage            Manage           52000
# 462779            53014            Boussu            Boussu           53000
#
#                 TX_ADM_DSTR_DESCR_NL             TX_ADM_DSTR_DESCR_FR  \
# 0            Arrondissement Borgworm        Arrondissement de Waremme
# 1            Arrondissement Borgworm        Arrondissement de Waremme
# 2             Arrondissement Hasselt        Arrondissement de Hasselt
# 3             Arrondissement Hasselt        Arrondissement de Hasselt
# 4             Arrondissement Hasselt        Arrondissement de Hasselt
# ...                              ...                              ...
# 462775  Arrondissement Philippeville  Arrondissement de Philippeville
# 462776      Arrondissement Charleroi      Arrondissement de Charleroi
# 462777      Arrondissement Charleroi      Arrondissement de Charleroi
# 462778      Arrondissement Charleroi      Arrondissement de Charleroi
# 462779         Arrondissement Bergen           Arrondissement de Mons
#
#        CD_PROV_REFNIS      TX_PROV_DESCR_NL      TX_PROV_DESCR_FR  \
# 0               60000        Provincie Luik     Province de Liège
# 1               60000        Provincie Luik     Province de Liège
# 2               70000     Provincie Limburg  Province de Limbourg
# 3               70000     Provincie Limburg  Province de Limbourg
# 4               70000     Provincie Limburg  Province de Limbourg
# ...               ...                   ...                   ...
# 462775          90000       Provincie Namen     Province de Namur
# 462776          50000  Provincie Henegouwen   Province de Hainaut
# 462777          50000  Provincie Henegouwen   Province de Hainaut
# 462778          50000  Provincie Henegouwen   Province de Hainaut
# 462779          50000  Provincie Henegouwen   Province de Hainaut
#
#         CD_RGN_REFNIS  ... CD_SEX CD_NATLTY TX_NATLTY_FR   TX_NATLTY_NL  \
# 0                3000  ...      F       BEL       Belges         Belgen
# 1                3000  ...      M       BEL       Belges         Belgen
# 2                2000  ...      F       BEL       Belges         Belgen
# 3                2000  ...      M       BEL       Belges         Belgen
# 4                2000  ...      F       BEL       Belges         Belgen
# ...               ...  ...    ...       ...          ...            ...
# 462775           3000  ...      F       ETR    Etrangers  Vreemdelingen
# 462776           3000  ...      M       ETR    Etrangers  Vreemdelingen
# 462777           3000  ...      M       ETR    Etrangers  Vreemdelingen
# 462778           3000  ...      F       ETR    Etrangers  Vreemdelingen
# 462779           3000  ...      M       ETR    Etrangers  Vreemdelingen
#
#        CD_CIV_STS TX_CIV_STS_FR  TX_CIV_STS_NL CD_AGE MS_POPULATION  CD_YEAR
# 0              20         Marié         Gehuwd     81             2     2017
# 1              20         Marié         Gehuwd     29             3     2017
# 2              20         Marié         Gehuwd     89             7     2017
# 3              20         Marié         Gehuwd     39            27     2017
# 4              20         Marié         Gehuwd     71           127     2017
# ...           ...           ...            ...    ...           ...      ...
# 462775         40       Divorcé     Gescheiden     88             1     2017
# 462776         40       Divorcé     Gescheiden     53             3     2017
# 462777         40       Divorcé     Gescheiden     51             3     2017
# 462778         40       Divorcé     Gescheiden     49             3     2017
# 462779         40       Divorcé     Gescheiden     44             4     2017
#
# [462780 rows x 22 columns]

# %%
pobl_2017.shape
# Out:
# (462780, 22)

# %%
pobl_2017.describe(include="all")
# Out:
#         CD_MUNTY_REFNIS TX_MUNTY_DESCR_NL TX_MUNTY_DESCR_FR  CD_DSTR_REFNIS  \
# count     462780.000000            462780            462780   462780.000000
# unique              NaN               589               589             NaN
# top                 NaN         Antwerpen            Anvers             NaN
# freq                NaN              1288              1288             NaN
# mean       45806.173711               NaN               NaN    45765.674835
# std        23953.152692               NaN               NaN    23947.466347
# min        11001.000000               NaN               NaN    11000.000000
# 25%        24038.000000               NaN               NaN    24000.000000
# 50%        44045.000000               NaN               NaN    44000.000000
# 75%        63035.000000               NaN               NaN    63000.000000
# max        93090.000000               NaN               NaN    93000.000000
#
#                   TX_ADM_DSTR_DESCR_NL            TX_ADM_DSTR_DESCR_FR  \
# count                           462780                          462780
# unique                              43                              43
# top     Arrondissement Halle-Vilvoorde  Arrondissement de Hal-Vilvorde
# freq                             28885                           28885
# mean                               NaN                             NaN
# std                                NaN                             NaN
# min                                NaN                             NaN
# 25%                                NaN                             NaN
# 50%                                NaN                             NaN
# 75%                                NaN                             NaN
# max                                NaN                             NaN
#
#         CD_PROV_REFNIS TX_PROV_DESCR_NL   TX_PROV_DESCR_FR  CD_RGN_REFNIS  \
# count         462780.0           462780             462780  462780.000000
# unique            21.0               11                 11            NaN
# top            40000.0   Provincie Luik  Province de Liège            NaN
# freq           38322.0            61888              61888            NaN
# mean               NaN              NaN                NaN    2519.127879
# std                NaN              NaN                NaN     584.858025
# min                NaN              NaN                NaN    2000.000000
# 25%                NaN              NaN                NaN    2000.000000
# 50%                NaN              NaN                NaN    2000.000000
# 75%                NaN              NaN                NaN    3000.000000
# max                NaN              NaN                NaN    4000.000000
#
#         ...  CD_SEX CD_NATLTY TX_NATLTY_FR TX_NATLTY_NL     CD_CIV_STS  \
# count   ...  462780    462780       462780       462780  462780.000000
# unique  ...       2         2            2            2            NaN
# top     ...       F       BEL       Belges       Belgen            NaN
# freq    ...  238213    309399       309399       309399            NaN
# mean    ...     NaN       NaN          NaN          NaN      22.105190
# std     ...     NaN       NaN          NaN          NaN      11.209627
# min     ...     NaN       NaN          NaN          NaN      10.000000
# 25%     ...     NaN       NaN          NaN          NaN      10.000000
# 50%     ...     NaN       NaN          NaN          NaN      20.000000
# 75%     ...     NaN       NaN          NaN          NaN      30.000000
# max     ...     NaN       NaN          NaN          NaN      40.000000
#
#        TX_CIV_STS_FR  TX_CIV_STS_NL         CD_AGE  MS_POPULATION   CD_YEAR
# count         462780         462780  462780.000000  462780.000000  462780.0
# unique             4              4            NaN            NaN       NaN
# top      Célibataire       Ongehuwd            NaN            NaN       NaN
# freq          160242         160242            NaN            NaN       NaN
# mean             NaN            NaN      52.469160      24.465379    2017.0
# std              NaN            NaN      23.426036      63.748085       0.0
# min              NaN            NaN       0.000000       1.000000    2017.0
# 25%              NaN            NaN      35.000000       2.000000    2017.0
# 50%              NaN            NaN      53.000000       6.000000    2017.0
# 75%              NaN            NaN      71.000000      24.000000    2017.0
# max              NaN            NaN     100.000000    2944.000000    2017.0
#
# [11 rows x 22 columns]

# %%
pobl_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462780 entries, 0 to 462779
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CD_MUNTY_REFNIS       462780 non-null  int64
#  1   TX_MUNTY_DESCR_NL     462780 non-null  object
#  2   TX_MUNTY_DESCR_FR     462780 non-null  object
#  3   CD_DSTR_REFNIS        462780 non-null  int64
#  4   TX_ADM_DSTR_DESCR_NL  462780 non-null  object
#  5   TX_ADM_DSTR_DESCR_FR  462780 non-null  object
#  6   CD_PROV_REFNIS        462780 non-null  object
#  7   TX_PROV_DESCR_NL      462780 non-null  object
#  8   TX_PROV_DESCR_FR      462780 non-null  object
#  9   CD_RGN_REFNIS         462780 non-null  int64
#  10  TX_RGN_DESCR_NL       462780 non-null  object
#  11  TX_RGN_DESCR_FR       462780 non-null  object
#  12  CD_SEX                462780 non-null  object
#  13  CD_NATLTY             462780 non-null  object
#  14  TX_NATLTY_FR          462780 non-null  object
#  15  TX_NATLTY_NL          462780 non-null  object
#  16  CD_CIV_STS            462780 non-null  int64
#  17  TX_CIV_STS_FR         462780 non-null  object
#  18  TX_CIV_STS_NL         462780 non-null  object
#  19  CD_AGE                462780 non-null  int64
#  20  MS_POPULATION         462780 non-null  int64
#  21  CD_YEAR               462780 non-null  int64
# dtypes: int64(7), object(15)
# memory usage: 77.7+ MB

# %% [markdown]
# ## I.3. Limpiamos el dataframe
#
# ### 1.3.1. Quitamos las columnas irrelevantes para nuestro propósito
# Los únicos datos requeridos son: número de habitantes por "arrondissement" => las únicas columnas por guardar son: TX_PROV_DESCR_NL, TX_ADM_DSTR_DESCR_NL + MS_POPULATION

# %%
pobl_2017_col = pobl_2017.loc[:,["TX_PROV_DESCR_NL", "TX_ADM_DSTR_DESCR_NL","MS_POPULATION"]]
pobl_2017_col.head()
# Out:
#     TX_PROV_DESCR_NL     TX_ADM_DSTR_DESCR_NL  MS_POPULATION
# 0     Provincie Luik  Arrondissement Borgworm              2
# 1     Provincie Luik  Arrondissement Borgworm              3
# 2  Provincie Limburg   Arrondissement Hasselt              7
# 3  Provincie Limburg   Arrondissement Hasselt             27
# 4  Provincie Limburg   Arrondissement Hasselt            127

# %%
pobl_2017_col.columns
# Out:
# Index(['TX_PROV_DESCR_NL', 'TX_ADM_DSTR_DESCR_NL', 'MS_POPULATION'], dtype='object')

# %%
#adaptar los nombres de títulos e integrarlos en el dataframe:
pobl_2017_col.columns = shorten_column_titles(pobl_2017_col.columns)
pobl_2017_col.head()
# Out:
#                 PROV                 ADM_DSTR  MS_POPULATION
# 0     Provincie Luik  Arrondissement Borgworm              2
# 1     Provincie Luik  Arrondissement Borgworm              3
# 2  Provincie Limburg   Arrondissement Hasselt              7
# 3  Provincie Limburg   Arrondissement Hasselt             27
# 4  Provincie Limburg   Arrondissement Hasselt            127

# %% [markdown]
# ### I.3.2. Tratamos los valores no disponibles (emergidos en el I.2)

# %% [markdown]
# a) Identificamos las columnas concretas dónde se sitúan los valores no disponibles de una manera más visible que por el método .info() en el I.2.

# %%
#guardamos los últimos cambios en la variables pobl_2017
pobl_2017 = pobl_2017_col
pobl_2017_col.isnull().any()
# Out:
# PROV             False
# ADM_DSTR         False
# MS_POPULATION    False
# dtype: bool

# %% [markdown]
# b) Apreciamos la cantidad de valores no disponibles (nº de registros en los cuales se manifiestan)

# %%
pobl_2017.isnull().sum()
# Out:
# PROV             0
# ADM_DSTR         0
# MS_POPULATION    0
# dtype: int64

# %% [markdown]
# c) Con vistas a la sustitución de estos valores: verificamos primero si el número de 21492 corresponde al número de filas que conciernan solo al arrondissement Brussel-Hoofdstad

# %%
#primer sondeo mediante sample:
nan_rows = pobl_2017[pobl_2017.isnull().any(1)]
nan_rows.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23432\2843975411.py in <module>
#       1 #primer sondeo mediante sample:
#       2 nan_rows = pobl_2017[pobl_2017.isnull().any(1)]
# ----> 3 nan_rows.sample(5)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5363             )
#    5364
# -> 5365         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5366         result = self.take(locs, axis=axis)
#    5367         if ignore_index:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
#cuento exacto:
sum(pobl_2017['ADM_DSTR'] == 'Arrondissement Brussel-Hoofdstad')
# Out:
# 21492

# %% [markdown]
# Conclusión: el número de filas sin valor disponible corresponde exactamente al número de filas que contienen "Arrondissement Brussel-Hoofdstad", ni más, ni menos. Por lo tanto, sabemos con certeza que todas las sustituciones se situarán en este "arrondissement". Para no perder datos en posteriores visualizaciones o tratamientos de datos en base a 'provincia', vamos a 'copiar' los valores de arrondissement a la columna de provincia. Así, siempre que llamemos a este dataframe (o de manera más concreta, a sus provincias), estaremos seguros de que no hay ningún valor NaN, y entrarán en consideración siempre los datos de la capital, aunque la 'etiqueta' no pueda considerarse propiamente como una provincia.

# %% [markdown]
# d) Sustituimos todos los valores "NaN" por "Arr. Brussel-Hoofdstad[no Prov]"

# %%
pobl_2017['PROV'] = pobl_2017['PROV'].fillna("Arr. Brussel-Hfdstad[no Prov]")

# %%
#verificamos si ahora nuestro dataframe se ha quedado sin valores NaN
pobl_2017.isnull().sum()
# Out:
# PROV             0
# ADM_DSTR         0
# MS_POPULATION    0
# dtype: int64

# %% [markdown]
# Ya está limpio pobl_2017: no quedan más valores Nan.

# %% [markdown]
# ### I.3.3. Agrupamos las filas por 'provincia' y 'arrondissement' para obtener así el nº total de habitantes por 'arrondissement'. Optamos por mantener las provincias para que todos puedan situar con más facilidad los 'arrondissmenten'.

# %% [markdown]
# ### a) agrupación de número de habitantes a nivel de 'arrondissement'

# %%
pobl_2017_habxarr = pobl_2017.groupby(["PROV","ADM_DSTR"])[["PROV","ADM_DSTR", "MS_POPULATION"]].sum()
pobl_2017_habxarr
# Out:
#                                                             MS_POPULATION
# PROV                      ADM_DSTR
#                           Arrondissement Brussel-Hoofdstad        1191604
# Provincie Antwerpen       Arrondissement Antwerpen                1039943
#                           Arrondissement Mechelen                  340410
#                           Arrondissement Turnhout                  455677
# Provincie Henegouwen      Arrondissement Aat                        86719
#                           Arrondissement Bergen                    258431
#                           Arrondissement Charleroi                 430128
#                           Arrondissement Doornik                   146910
#                           Arrondissement Moeskroen                  75875
#                           Arrondissement Thuin                     151699
#                           Arrondissement Zinnik                    189800
# Provincie Limburg         Arrondissement Hasselt                   425270
#                           Arrondissement Maaseik                   239842
#                           Arrondissement Tongeren                  202301
# Provincie Luik            Arrondissement Borgworm                   80181
#                           Arrondissement Hoei                      112786
#                           Arrondissement Luik                      622841
#                           Arrondissement Verviers                  286723
# Provincie Luxemburg       Arrondissement Aarlen                     61899
#                           Arrondissement Bastenaken                 47844
#                           Arrondissement Marche-en-Famenne          55952
#                           Arrondissement Neufchâteau                62777
#                           Arrondissement Virton                     53500
# Provincie Namen           Arrondissement Dinant                    110335
#                           Arrondissement Namen                     314541
#                           Arrondissement Philippeville              66409
# Provincie Oost-Vlaanderen Arrondissement Aalst                     286741
#                           Arrondissement Dendermonde               199553
#                           Arrondissement Eeklo                      84113
#                           Arrondissement Gent                      553961
#                           Arrondissement Oudenaarde                123330
#                           Arrondissement Sint-Niklaas              248489
# Provincie Vlaams-Brabant  Arrondissement Halle-Vilvoorde           627247
#                           Arrondissement Leuven                    502602
# Provincie Waals-Brabant   Arrondissement Nijvel                    399123
# Provincie West-Vlaanderen Arrondissement Brugge                    281256
#                           Arrondissement Diksmuide                  51250
#                           Arrondissement Ieper                     106230
#                           Arrondissement Kortrijk                  287823
#                           Arrondissement Oostende                  155717
#                           Arrondissement Roeselare                 150742
#                           Arrondissement Tielt                      92355
#                           Arrondissement Veurne                     61159

# %%
#reset index para merge en base a columnas idénticas
pobl_2017_habxarr.reset_index(inplace=True)

# %%
#verificación: nuevo índice? sí
pobl_2017_habxarr
# Out:
#                          PROV                          ADM_DSTR  MS_POPULATION
# 0                              Arrondissement Brussel-Hoofdstad        1191604
# 1         Provincie Antwerpen          Arrondissement Antwerpen        1039943
# 2         Provincie Antwerpen           Arrondissement Mechelen         340410
# 3         Provincie Antwerpen           Arrondissement Turnhout         455677
# 4        Provincie Henegouwen                Arrondissement Aat          86719
# 5        Provincie Henegouwen             Arrondissement Bergen         258431
# 6        Provincie Henegouwen          Arrondissement Charleroi         430128
# 7        Provincie Henegouwen            Arrondissement Doornik         146910
# 8        Provincie Henegouwen          Arrondissement Moeskroen          75875
# 9        Provincie Henegouwen              Arrondissement Thuin         151699
# 10       Provincie Henegouwen             Arrondissement Zinnik         189800
# 11          Provincie Limburg            Arrondissement Hasselt         425270
# 12          Provincie Limburg            Arrondissement Maaseik         239842
# 13          Provincie Limburg           Arrondissement Tongeren         202301
# 14             Provincie Luik           Arrondissement Borgworm          80181
# 15             Provincie Luik               Arrondissement Hoei         112786
# 16             Provincie Luik               Arrondissement Luik         622841
# 17             Provincie Luik           Arrondissement Verviers         286723
# 18        Provincie Luxemburg             Arrondissement Aarlen          61899
# 19        Provincie Luxemburg         Arrondissement Bastenaken          47844
# 20        Provincie Luxemburg  Arrondissement Marche-en-Famenne          55952
# 21        Provincie Luxemburg        Arrondissement Neufchâteau          62777
# 22        Provincie Luxemburg             Arrondissement Virton          53500
# 23            Provincie Namen             Arrondissement Dinant         110335
# 24            Provincie Namen              Arrondissement Namen         314541
# 25            Provincie Namen      Arrondissement Philippeville          66409
# 26  Provincie Oost-Vlaanderen              Arrondissement Aalst         286741
# 27  Provincie Oost-Vlaanderen        Arrondissement Dendermonde         199553
# 28  Provincie Oost-Vlaanderen              Arrondissement Eeklo          84113
# 29  Provincie Oost-Vlaanderen               Arrondissement Gent         553961
# 30  Provincie Oost-Vlaanderen         Arrondissement Oudenaarde         123330
# 31  Provincie Oost-Vlaanderen       Arrondissement Sint-Niklaas         248489
# 32   Provincie Vlaams-Brabant    Arrondissement Halle-Vilvoorde         627247
# 33   Provincie Vlaams-Brabant             Arrondissement Leuven         502602
# 34    Provincie Waals-Brabant             Arrondissement Nijvel         399123
# 35  Provincie West-Vlaanderen             Arrondissement Brugge         281256
# 36  Provincie West-Vlaanderen          Arrondissement Diksmuide          51250
# 37  Provincie West-Vlaanderen              Arrondissement Ieper         106230
# 38  Provincie West-Vlaanderen           Arrondissement Kortrijk         287823
# 39  Provincie West-Vlaanderen           Arrondissement Oostende         155717
# 40  Provincie West-Vlaanderen          Arrondissement Roeselare         150742
# 41  Provincie West-Vlaanderen              Arrondissement Tielt          92355
# 42  Provincie West-Vlaanderen             Arrondissement Veurne          61159

# %% [markdown]
# ### b) agrupación de nº de habitantes por provincia (Bxl: arrondissment)

# %%
pobl_2017_habxprov = pobl_2017_habxarr.groupby("PROV")[["PROV","MS_POPULATION"]].sum()
pobl_2017_habxprov
# Out:
#                            MS_POPULATION
# PROV
#                                  1191604
# Provincie Antwerpen              1836030
# Provincie Henegouwen             1339562
# Provincie Limburg                 867413
# Provincie Luik                   1102531
# Provincie Luxemburg               281972
# Provincie Namen                   491285
# Provincie Oost-Vlaanderen        1496187
# Provincie Vlaams-Brabant         1129849
# Provincie Waals-Brabant           399123
# Provincie West-Vlaanderen        1186532

# %% [markdown]
# ### c) agrupación de nº de habitantes a nivel de país

# %%
hab_2017_BE = pobl_2017["MS_POPULATION"].sum()
hab_2017_BE
# Out:
# 11322088

# %% [markdown]
# ### d) nº de habitantes por "arrondissement": cifras absolutas y proporcionales respecto a la totalidad de la población belga

# %%
pobl_2017_habxarr["PROPORTION_BE"] = pobl_2017_habxarr["MS_POPULATION"]/pobl_2017_habxarr["MS_POPULATION"].sum()
#por haber querido cambiar título nueva columna de PROPORCIÓN a PROPORCIÓN_BE, quitar la penúltima columna PROPORCION
#luego lo mismo con PROPORCIÓN_BE > PROPORTION_BE
#pobl_2017_habxarr.drop("PROPORCIÓN", axis=1, inplace=True)
#pobl_2017_habxarr.drop("PROPORCIÓN_BE", axis = 1, inplace=True)
pobl_2017_habxarr
# Out:
#                          PROV                          ADM_DSTR  \
# 0                              Arrondissement Brussel-Hoofdstad
# 1         Provincie Antwerpen          Arrondissement Antwerpen
# 2         Provincie Antwerpen           Arrondissement Mechelen
# 3         Provincie Antwerpen           Arrondissement Turnhout
# 4        Provincie Henegouwen                Arrondissement Aat
# 5        Provincie Henegouwen             Arrondissement Bergen
# 6        Provincie Henegouwen          Arrondissement Charleroi
# 7        Provincie Henegouwen            Arrondissement Doornik
# 8        Provincie Henegouwen          Arrondissement Moeskroen
# 9        Provincie Henegouwen              Arrondissement Thuin
# 10       Provincie Henegouwen             Arrondissement Zinnik
# 11          Provincie Limburg            Arrondissement Hasselt
# 12          Provincie Limburg            Arrondissement Maaseik
# 13          Provincie Limburg           Arrondissement Tongeren
# 14             Provincie Luik           Arrondissement Borgworm
# 15             Provincie Luik               Arrondissement Hoei
# 16             Provincie Luik               Arrondissement Luik
# 17             Provincie Luik           Arrondissement Verviers
# 18        Provincie Luxemburg             Arrondissement Aarlen
# 19        Provincie Luxemburg         Arrondissement Bastenaken
# 20        Provincie Luxemburg  Arrondissement Marche-en-Famenne
# 21        Provincie Luxemburg        Arrondissement Neufchâteau
# 22        Provincie Luxemburg             Arrondissement Virton
# 23            Provincie Namen             Arrondissement Dinant
# 24            Provincie Namen              Arrondissement Namen
# 25            Provincie Namen      Arrondissement Philippeville
# 26  Provincie Oost-Vlaanderen              Arrondissement Aalst
# 27  Provincie Oost-Vlaanderen        Arrondissement Dendermonde
# 28  Provincie Oost-Vlaanderen              Arrondissement Eeklo
# 29  Provincie Oost-Vlaanderen               Arrondissement Gent
# 30  Provincie Oost-Vlaanderen         Arrondissement Oudenaarde
# 31  Provincie Oost-Vlaanderen       Arrondissement Sint-Niklaas
# 32   Provincie Vlaams-Brabant    Arrondissement Halle-Vilvoorde
# 33   Provincie Vlaams-Brabant             Arrondissement Leuven
# 34    Provincie Waals-Brabant             Arrondissement Nijvel
# 35  Provincie West-Vlaanderen             Arrondissement Brugge
# 36  Provincie West-Vlaanderen          Arrondissement Diksmuide
# 37  Provincie West-Vlaanderen              Arrondissement Ieper
# 38  Provincie West-Vlaanderen           Arrondissement Kortrijk
# 39  Provincie West-Vlaanderen           Arrondissement Oostende
# 40  Provincie West-Vlaanderen          Arrondissement Roeselare
# 41  Provincie West-Vlaanderen              Arrondissement Tielt
# 42  Provincie West-Vlaanderen             Arrondissement Veurne
#
#     MS_POPULATION  PROPORTION_BE
# 0         1191604       0.105246
# 1         1039943       0.091851
# 2          340410       0.030066
# 3          455677       0.040247
# 4           86719       0.007659
# 5          258431       0.022825
# 6          430128       0.037990
# 7          146910       0.012976
# 8           75875       0.006702
# 9          151699       0.013399
# 10         189800       0.016764
# 11         425270       0.037561
# 12         239842       0.021184
# 13         202301       0.017868
# 14          80181       0.007082
# 15         112786       0.009962
# 16         622841       0.055011
# 17         286723       0.025324
# 18          61899       0.005467
# 19          47844       0.004226
# 20          55952       0.004942
# 21          62777       0.005545
# 22          53500       0.004725
# 23         110335       0.009745
# 24         314541       0.027781
# 25          66409       0.005865
# 26         286741       0.025326
# 27         199553       0.017625
# 28          84113       0.007429
# 29         553961       0.048927
# 30         123330       0.010893
# 31         248489       0.021947
# 32         627247       0.055400
# 33         502602       0.044391
# 34         399123       0.035252
# 35         281256       0.024841
# 36          51250       0.004527
# 37         106230       0.009383
# 38         287823       0.025421
# 39         155717       0.013753
# 40         150742       0.013314
# 41          92355       0.008157
# 42          61159       0.005402

# %% [markdown]
# ### e) nº de habitantes por "provincia": cifras absolutas y proporcionales respecto a la totalidad de la población belga

# %%
pobl_2017_habxprov["PROPORCIÓN_BE"] = pobl_2017_habxprov["MS_POPULATION"]/pobl_2017_habxprov["MS_POPULATION"].sum()
pobl_2017_habxprov
# Out:
#                            MS_POPULATION  PROPORCIÓN_BE
# PROV
#                                  1191604       0.105246
# Provincie Antwerpen              1836030       0.162164
# Provincie Henegouwen             1339562       0.118314
# Provincie Limburg                 867413       0.076612
# Provincie Luik                   1102531       0.097379
# Provincie Luxemburg               281972       0.024905
# Provincie Namen                   491285       0.043392
# Provincie Oost-Vlaanderen        1496187       0.132148
# Provincie Vlaams-Brabant         1129849       0.099792
# Provincie Waals-Brabant           399123       0.035252
# Provincie West-Vlaanderen        1186532       0.104798

# %% [markdown]
# ## I.4 Preparación de ficheros para exportar

# %%
pobl_2017_habxarr.to_csv("Data_ACC/pobl_2017_habxarr.csv", index = False)
pobl_2017_habxprov.to_csv("Data_ACC/pobl_2017_habxprov.csv", index = False)
#cambios para hab_2017_BE porque como numpy.array no admite escritura a csv
hab_2017_BE.tofile('Data_acc/hab_2017_BE.csv', sep = ',')
