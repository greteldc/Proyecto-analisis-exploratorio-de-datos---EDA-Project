# %% [markdown]
# # **Título con el contenido concreto del Notebook/fichero .py**
#
# # 1. Importaciones
#   ## I.1. software de librerías
#   ## I.2. datos de ficheros propios
#
# <br>
# <br>
#
# # II. El dataset: primera exploración de los datos
#
# <br>
# <br>
#
# # III. Limpieza de los datos en función de los requisitos para analizar la hipótesis formulada
#
#   ## III.1 Limpieza para que se ajuste mejor el dataframe al contenido:
#
#     a) quitar columnas no relevantes o duplicadas
#     b) quitar filas no relevantes o duplicadas
#     c) añadir columnas/filas con nuevos datos calculados en base a los datos ya disponbles
#
#   ## III.2 Limpieza de layout:
#
#     a) renombrar títulos (para que sean más transparentes, para que no haya 2 nombres iguales que cubren contenido distinto, para quitar indicaciones suplementarias de columnas identificadas por 'idénticas' después de una operación de merge)
#     b) renombrar valores en el dataframe
#     c) (re)set índices
#
#   ### el recorrido por III.1 y III.2 es un proceso iterativo que finaliza al tener el dataframe limpio tanto en lo que concierne al contenido como en lo que concierne al layout
#
# <br>
# <br>
#
#
# # IV. Análisis
#
#   ## IV.1 Fase preparativa:
#
#     a) juntar datos (merge, concatenate, join)
#     b) cálculo de nuevos datos (si no hecho todavía en la fase III)
#     c) si hace falta: volver a fase III
#
#   ## IV.2 Análisis
#
#     a) análisis de variabilidad
#         - estadístico (varianza, dispersión, ...)
#
#
# <br>
# <br>
#
# # V. Visualización de los datos analizados y su resultado
#
#   ## V.1. Determinar la forma más adecuada para la visualización
#
#      - en función del número de variables
#      &
#      - en función del tipo de estadística que se quiere mostrar
#
# <br>
# <br>
#
# # VI. Presentación
#
#     - con respuesta a las preguntas/hipótesis iniciales
#     - con eventuales pistas para exploración más profunda / alternativa
